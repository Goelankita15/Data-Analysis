# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as Be #for web scraping purpose

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
url = 'https://www.ambitionbox.com/list-of-companies?sortBy=popular&page={}'  # Remove the space between `pages=` and `4`
webPage = requests.get(url, headers = headers).text

# %%
soup = Be(webPage, 'lxml')

# %%
# soup.find_all('h2') #list of all the items of h2 
# # strip to remove the formatting of the h2 tag
# companies = []
# for i in soup.find_all('h2', class_ = 'companyCardWrapper__companyName'): 
#     companies.append(i.text)
# len(soup.find_all('h2', class_ = 'companyCardWrapper__companyName'))

# %%
# Rating = []
# for i in soup.find_all('span', class_ = 'companyCardWrapper__companyRatingValue'):
#     Rating.append(i.text)
    
# len(soup.find_all('span', class_ = 'companyCardWrapper__companyRatingValue'))

# %%
# Reviews = []
# for i in soup.find_all('span', class_ = 'companyCardWrapper__ActionCount'):
#     Reviews.append(i.text)
    
# len(soup.find_all('span', class_ = 'companyCardWrapper__ActionCount'))
# Reviews

# %% [markdown]
# # Fetching the Data of all the companies in form of blocks first then gettting all the information one by one

# %%
get = soup.find_all('div', class_ = 'companyCardWrapper')

# %%
name = []
rating = []
about = []
sec =[]
Location = []
Employes = []
Age = []
domain=[]
for i in soup.find_all('div', class_ = 'companyCardWrapper'):
    company_name = i.find_all('h2', class_ = 'companyCardWrapper__companyName')
    name.append(company_name[0].text.strip())
    rating_value = i.find_all('span', class_ = 'companyCardWrapper__companyRatingValue')
    rating.append(rating_value[0].text)
    info = i.find_all('span', class_ = 'companyCardWrapper__interLinking')
    about.append(info[0].text.strip())
    
for item in about:
    parts = item.split('|')
    if len(parts) >= 5:  
        domain.append(parts[0].strip()) 
        Employes.append(parts[1].strip())  
        sec.append(parts[2].strip())  
        Age.append(parts[3].strip())  
        Location.append(parts[4].strip())  
    else:
        domain.append(parts[0].strip())  
        Employes.append(parts[1].strip()) 
        Age.append(parts[2].strip())  
        Location.append(parts[3].strip())  
        sec.append('None')  
d = {'Comapany_name': name, 'Rating': rating, 'Sector':sec, 'Domain':domain,'Employees':Employes,'Age':Age, 'Location':Location}
df = pd.DataFrame(d)

# %%
df
# Out:
#                  Comapany_name Rating             Sector  \
# 0                Vodafone Idea    4.1             Public
# 1                       BYJU'S    3.0     Indian Unicorn
# 2          Kotak Mahindra Bank    3.8             Public
# 3                     Deloitte    3.9               None
# 4          Reliance Industries    4.0             Public
# 5                   iEnergizer    4.7               None
# 6                Bharti Airtel    4.0             Public
# 7                  Tata Motors    4.2             Public
# 8                     Flipkart    4.0             Public
# 9                          WNS    3.5               None
# 10               IndusInd Bank    3.7             Public
# 11               Ernst & Young    3.6               None
# 12       AU Small Finance Bank    4.5  Fortune India 500
# 13         Mahindra & Mahindra    4.1             Public
# 14                 Infosys BPM    3.8               None
# 15              DXC Technology    3.8             Public
# 16             IDFC FIRST Bank    4.0             Public
# 17  Conneqt Business Solutions    3.8               None
# 18                   HDFC Life    4.1             Public
# 19                 LTIMindtree    3.6             Public
#
#                       Domain             Employees            Age  \
# 0                    Telecom      5k-10k Employees    6 years old
# 1                     EdTech     10k-50k Employees   13 years old
# 2                    Banking  50k-1 Lakh Employees   21 years old
# 3      Management Consulting     1 Lakh+ Employees  179 years old
# 4                  Oil & Gas     1 Lakh+ Employees   47 years old
# 5                        BPO     10k-50k Employees   24 years old
# 6                    Telecom     10k-50k Employees   29 years old
# 7                 Automobile     10k-50k Employees   79 years old
# 8                   Internet     10k-50k Employees   17 years old
# 9                        BPO     10k-50k Employees   28 years old
# 10                   Banking     10k-50k Employees   30 years old
# 11     Management Consulting  50k-1 Lakh Employees   22 years old
# 12                   Banking     10k-50k Employees   28 years old
# 13                Automobile     1 Lakh+ Employees   79 years old
# 14                       BPO     10k-50k Employees   22 years old
# 15  IT Services & Consulting     10k-50k Employees    7 years old
# 16                   Banking     10k-50k Employees    6 years old
# 17                       BPO     10k-50k Employees   22 years old
# 18                 Insurance     10k-50k Employees   24 years old
# 19  IT Services & Consulting  50k-1 Lakh Employees   25 years old
#
#                         Location
# 0               Mumbai +639 more
# 1            Bangalore +305 more
# 2               Mumbai +563 more
# 3               London +145 more
# 4          Navi Mumbai +667 more
# 5                 Noida +27 more
# 6     Gurgaon/Gurugram +650 more
# 7                 Pune +453 more
# 8            Bangalore +530 more
# 9                Mumbai +36 more
# 10    Gurgaon/Gurugram +677 more
# 11               London +97 more
# 12              Jaipur +401 more
# 13              Mumbai +472 more
# 14  Bangalore/Bengaluru +66 more
# 15               Minato +81 more
# 16              Mumbai +574 more
# 17              Mumbai +219 more
# 18              Mumbai +549 more
# 19  Bangalore/Bengaluru +51 more

# %%
final = pd.DataFrame()
for data in range(1, 34):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
    url = 'https://www.ambitionbox.com/list-of-companies?sortBy=popular&page={}'.format(data)
    webPage = requests.get(url, headers = headers).text
    soup = Be(webPage, 'lxml')
    name = []
    rating = []
    about = []
    sec =[]
    Location = []
    Employes = []
    Age = []
    domain=[]
    for i in soup.find_all('div', class_ = 'companyCardWrapper'):
        company_name = i.find_all('h2', class_ = 'companyCardWrapper__companyName')
        name.append(company_name[0].text.strip())
        rating_value = i.find_all('span', class_ = 'companyCardWrapper__companyRatingValue')
        rating.append(rating_value[0].text)
        info = i.find_all('span', class_ = 'companyCardWrapper__interLinking')
        about.append(info[0].text.strip())

    for item in about:
        parts = item.split('|')
        if len(parts) >= 5:  
            domain.append(parts[0].strip()) 
            Employes.append(parts[1].strip())  
            sec.append(parts[2].strip())  
            Age.append(parts[3].strip())  
            Location.append(parts[4].strip())  
        else:
            domain.append('None')  
            Employes.append('None') 
            Age.append('None')  
            Location.append('None')  
            sec.append('None')  
    d = {'Comapany_name': name, 'Rating': rating, 'Sector':sec, 'Domain':domain,'Employees':Employes,'Age':Age, 'Location':Location}
    df = pd.DataFrame(d) 
    final = pd.concat([final, df], ignore_index=True)

# %%
final = pd.DataFrame(final)

# %%
final.shape
# Out:
# (660, 7)

# %%
final.to_csv('Comapnies.csv')

# %%
final
# Out:
#                  Comapany_name Rating              Sector  \
# 0                          TCS    3.7              Public
# 1                    Accenture    4.0              Public
# 2                    Cognizant    3.8  Forbes Global 2000
# 3                        Wipro    3.7              Public
# 4                    Capgemini    3.8              Public
# ..                         ...    ...                 ...
# 655                    JioMart    3.7                None
# 656                Aye Finance    4.1             Startup
# 657               Godrej Group    3.9              Public
# 658  Ocwen Financial Solutions    4.1                None
# 659              MiraMed Ajuba    3.8                None
#
#                        Domain          Employees            Age  \
# 0    IT Services & Consulting  1 Lakh+ Employees   56 years old
# 1    IT Services & Consulting  1 Lakh+ Employees   35 years old
# 2    IT Services & Consulting  1 Lakh+ Employees   30 years old
# 3    IT Services & Consulting  1 Lakh+ Employees   79 years old
# 4    IT Services & Consulting  1 Lakh+ Employees   57 years old
# ..                        ...                ...            ...
# 655                      None               None           None
# 656                      NBFC   5k-10k Employees   11 years old
# 657                 Chemicals  10k-50k Employees  127 years old
# 658                      None               None           None
# 659                      None               None           None
#
#                            Location
# 0                  Mumbai +339 more
# 1                  Dublin +169 more
# 2    Teaneck. New Jersey. +156 more
# 3     Bangalore/Bengaluru +276 more
# 4                   Paris +138 more
# ..                              ...
# 655                            None
# 656                 Delhi +232 more
# 657                Mumbai +111 more
# 658                            None
# 659                            None
#
# [660 rows x 7 columns]
